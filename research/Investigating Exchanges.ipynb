# %% [markdown]
# ### Imports

# %%
from livecoindata import grab_all_exchanges
from grab_coins import grab_symbols
import pprint

# %% [markdown]
# ## Research: Exchanges & Usable Markets
#
# ### Purpose
#
# We want to find what exchanges we can use out of the box, and what exchanges we need to add extra code for to process the various symbols into the standardized format found on coinmarketcap.com.
#
# ### Process
#
# First, let's grab a dictionary of all exchanges and their market symbols available on ccxt.
#
# Then, let's grab a list of all cleaned symbols as scraped from coinmarketcap.com.
#
# Let's take both & create a list of all possible exchanges & markets that we can use that use these symbol formats and classic format "BaseCoinSymbol/QuoteCoinSymbol".
#
# We should also find all exchanges & symbols that do not follow these formats and list them out seperately.

# %%
exchanges_dict = grab_all_exchanges()
symbols = grab_symbols()
symbols = symbols + ["USD", "CAD"] #add fiat currencies that I want to see manually
# Out:
# Number of Exchanges:
# 97

# %%
all_clean_markets = []
for quote_coin in symbols:
    for base_coin in symbols:
        curr_market = base_coin + "/" + quote_coin
        all_clean_markets.append(curr_market)
        
print("# of symbols: " + str(len(symbols)))
print("# of potential markets: " + str(len(all_clean_markets)))

clean_exchanges_dict = {}
dirty_exchanges_dict = {}

for exch_name, exch_markets in exchanges_dict.items():
    curr_clean = set(exch_markets).intersection(set(all_clean_markets))
    clean_exchanges_dict[exch_name] = curr_clean
    curr_dirty = set(exch_markets).difference(set(all_clean_markets))
    dirty_exchanges_dict[exch_name] = curr_clean
        
print("Clean Exchanges Data:")
pprint.pprint(clean_exchanges_dict)
print("Dirty Exchanges Data:")
pprint.pprint(dirty_exchanges_dict)
# Out:
# # of symbols: 1514
# # of potential markets: 2292196
# Clean Exchanges Data:
# {'_1btcxe': {'BTC/USD', 'BTC/CAD'},
#  'acx': {'UBTC/BTC', 'FUEL/BTC'},
#  'allcoin': {'ACC/BTC',
#              'ACT/BTC',
#              'AIDOC/ETH',
#              'ATN/BTC',
#              'ATN/ETH',
#              'ATN/QTUM',
#              'AWR/QTUM',
#              'BASH/BTC',
#              'BCD/BTC',
#              'BCH/BTC',
#              'BOT/QTUM',
#              'BTG/BTC',
#              'BTM/BTC',
#              'BTM/ETH',
#              'DBC/ETH',
#              'ENT/QTUM',
#              'ETH/BTC',
#              'FID/BTC',
#              'GAME/BTC',
#              'GNX/ETH',
#              'GXS/BTC',
#              'HLC/QTUM',
#              'HPB/BTC',
#              'HSR/BTC',
#              'INK/QTUM',
#              'INT/BTC',
#              'IQT/BTC',
#              'LTC/BTC',
#              'MDA/BTC',
#              'MDA/ETH',
#              'MGO/BTC',
#              'NAS/BTC',
#              'NEO/BTC',
#              'OC/BTC',
#              'OC/QTUM',
#              'PUT/QTUM',
#              'QBT/QTUM',
#              'QTUM/BTC',
#              'SIGMA/ETH',
#              'SPC/BTC',
#              'SPC/QTUM',
#              'TSL/QTUM',
#              'UGC/ETH',
#              'UIP/BTC',
#              'UIP/ETH',
#              'ZEC/BTC'},
#  'anxpro': {'LTC/BTC', 'DOGE/BTC', 'XRP/BTC', 'BTC/USD', 'BTC/CAD'},
#  'binance': {'ADA/BTC',
#              'ADA/ETH',
#              'ADX/BNB',
#              'ADX/BTC',
#              'ADX/ETH',
#              'AION/BNB',
#              'AION/BTC',
#              'AION/ETH',
#              'AMB/BNB',
#              'AMB/BTC',
#              'AMB/ETH',
#              'APPC/BNB',
#              'APPC/BTC',
#              'APPC/ETH',
#              'ARK/BTC',
#              'ARK/ETH',
#              'ARN/BTC',
#              'ARN/ETH',
#              'AST/BTC',
#              'AST/ETH',
#              'BAT/BNB',
#              'BAT/BTC',
#              'BAT/ETH',
#              'BCD/BTC',
#              'BCD/ETH',
#              'BCH/BNB',
#              'BCH/BTC',
#              'BCH/ETH',
#              'BCH/USDT',
#              'BCPT/BNB',
#              'BCPT/BTC',
#              'BCPT/ETH',
#              'BNB/BTC',
#              'BNB/ETH',
#              'BNB/USDT',
#              'BNT/BTC',
#              'BNT/ETH',
#              'BRD/BNB',
#              'BRD/BTC',
#              'BRD/ETH',
#              'BTC/USDT',
#              'BTG/BTC',
#              'BTG/ETH',
#              'BTS/BNB',
#              'BTS/BTC',
#              'BTS/ETH',
#              'CDT/BTC',
#              'CDT/ETH',
#              'CHAT/BTC',
#              'CHAT/ETH',
#              'CMT/BNB',
#              'CMT/BTC',
#              'CMT/ETH',
#              'CND/BNB',
#              'CND/BTC',
#              'CND/ETH',
#              'CTR/BTC',
#              'CTR/ETH',
#              'DASH/BTC',
#              'DASH/ETH',
#              'DGD/BTC',
#              'DGD/ETH',
#              'DLT/BNB',
#              'DLT/BTC',
#              'DLT/ETH',
#              'DNT/BTC',
#              'DNT/ETH',
#              'EDO/BTC',
#              'EDO/ETH',
#              'ELF/BTC',
#              'ELF/ETH',
#              'ENG/BTC',
#              'ENG/ETH',
#              'ENJ/BTC',
#              'ENJ/ETH',
#              'EOS/BTC',
#              'EOS/ETH',
#              'ETC/BTC',
#              'ETC/ETH',
#              'ETH/BTC',
#              'ETH/USDT',
#              'EVX/BTC',
#              'EVX/ETH',
#              'FUEL/BTC',
#              'FUEL/ETH',
#              'FUN/BTC',
#              'FUN/ETH',
#              'GAS/BTC',
#              'GTO/BNB',
#              'GTO/BTC',
#              'GTO/ETH',
#              'GVT/BTC',
#              'GVT/ETH',
#              'GXS/BTC',
#              'GXS/ETH',
#              'HSR/BTC',
#              'HSR/ETH',
#              'ICN/BTC',
#              'ICN/ETH',
#              'ICX/BNB',
#              'ICX/BTC',
#              'ICX/ETH',
#              'INS/BTC',
#              'INS/ETH',
#              'IOST/BTC',
#              'IOST/ETH',
#              'KMD/BTC',
#              'KMD/ETH',
#              'KNC/BTC',
#              'KNC/ETH',
#              'LEND/BTC',
#              'LEND/ETH',
#              'LINK/BTC',
#              'LINK/ETH',
#              'LRC/BTC',
#              'LRC/ETH',
#              'LSK/BNB',
#              'LSK/BTC',
#              'LSK/ETH',
#              'LTC/BNB',
#              'LTC/BTC',
#              'LTC/ETH',
#              'LTC/USDT',
#              'LUN/BTC',
#              'LUN/ETH',
#              'MANA/BTC',
#              'MANA/ETH',
#              'MCO/BNB',
#              'MCO/BTC',
#              'MCO/ETH',
#              'MDA/BTC',
#              'MDA/ETH',
#              'MOD/BTC',
#              'MOD/ETH',
#              'MTH/BTC',
#              'MTH/ETH',
#              'MTL/BTC',
#              'MTL/ETH',
#              'NAV/BNB',
#              'NAV/BTC',
#              'NAV/ETH',
#              'NEBL/BNB',
#              'NEBL/BTC',
#              'NEBL/ETH',
#              'NEO/BNB',
#              'NEO/BTC',
#              'NEO/ETH',
#              'NEO/USDT',
#              'NULS/BNB',
#              'NULS/BTC',
#              'NULS/ETH',
#              'OAX/BTC',
#              'OAX/ETH',
#              'OMG/BTC',
#              'OMG/ETH',
#              'OST/BNB',
#              'OST/BTC',
#              'OST/ETH',
#              'PIVX/BNB',
#              'PIVX/BTC',
#              'PIVX/ETH',
#              'POE/BTC',
#              'POE/ETH',
#              'POWR/BNB',
#              'POWR/BTC',
#              'POWR/ETH',
#              'PPT/BTC',
#              'PPT/ETH',
#              'QSP/BNB',
#              'QSP/BTC',
#              'QSP/ETH',
#              'QTUM/BTC',
#              'QTUM/ETH',
#              'RCN/BNB',
#              'RCN/BTC',
#              'RCN/ETH',
#              'RDN/BNB',
#              'RDN/BTC',
#              'RDN/ETH',
#              'REQ/BTC',
#              'REQ/ETH',
#              'RLC/BNB',
#              'RLC/BTC',
#              'RLC/ETH',
#              'SALT/BTC',
#              'SALT/ETH',
#              'SNGLS/BTC',
#              'SNGLS/ETH',
#              'SNM/BTC',
#              'SNM/ETH',
#              'SNT/BTC',
#              'SNT/ETH',
#              'STEEM/BNB',
#              'STEEM/BTC',
#              'STEEM/ETH',
#              'STORJ/BTC',
#              'STORJ/ETH',
#              'STRAT/BTC',
#              'STRAT/ETH',
#              'SUB/BTC',
#              'SUB/ETH',
#              'TNB/BTC',
#              'TNB/ETH',
#              'TNT/BTC',
#              'TNT/ETH',
#              'TRIG/BNB',
#              'TRIG/BTC',
#              'TRIG/ETH',
#              'TRX/BTC',
#              'TRX/ETH',
#              'VEN/BNB',
#              'VEN/BTC',
#              'VEN/ETH',
#              'VIB/BTC',
#              'VIB/ETH',
#              'VIBE/BTC',
#              'VIBE/ETH',
#              'WABI/BNB',
#              'WABI/BTC',
#              'WABI/ETH',
#              'WAVES/BNB',
#              'WAVES/BTC',
#              'WAVES/ETH',
#              'WINGS/BTC',
#              'WINGS/ETH',
#              'WTC/BNB',
#              'WTC/BTC',
#              'WTC/ETH',
#              'XLM/BNB',
#              'XLM/BTC',
#              'XLM/ETH',
#              'XMR/BTC',
#              'XMR/ETH',
#              'XRP/BTC',
#              'XRP/ETH',
#              'XVG/BTC',
#              'XVG/ETH',
#              'XZC/BNB',
#              'XZC/BTC',
#              'XZC/ETH',
#              'ZEC/BTC',
#              'ZEC/ETH',
#              'ZRX/BTC',
#              'ZRX/ETH'},
#  'bit2c': set(),
#  'bitbay': {'BCH/BTC',
#             'BCH/USD',
#             'BTC/USD',
#             'BTG/BTC',
#             'BTG/USD',
#             'DASH/BTC',
#             'DASH/USD',
#             'ETH/BTC',
#             'ETH/USD',
#             'GAME/BTC',
#             'GAME/USD',
#             'LSK/BTC',
#             'LSK/USD',
#             'LTC/BTC',
#             'LTC/USD'},
#  'bitcoincoid': {'BTS/BTC',
#                  'DASH/BTC',
#                  'DOGE/BTC',
#                  'ETH/BTC',
#                  'LTC/BTC',
#                  'NXT/BTC',
#                  'XEM/BTC',
#                  'XLM/BTC',
#                  'XRP/BTC'},
#  'bitfinex': {'AID/BTC',
#               'AID/ETH',
#               'AID/USD',
#               'AVT/BTC',
#               'AVT/ETH',
#               'AVT/USD',
#               'BAT/BTC',
#               'BAT/ETH',
#               'BAT/USD',
#               'BCH/BTC',
#               'BCH/ETH',
#               'BCH/USD',
#               'BTC/USD',
#               'BTG/BTC',
#               'BTG/USD',
#               'DASH/BTC',
#               'DASH/USD',
#               'DAT/BTC',
#               'DAT/ETH',
#               'DAT/USD',
#               'EDO/BTC',
#               'EDO/ETH',
#               'EDO/USD',
#               'ELF/BTC',
#               'ELF/ETH',
#               'ELF/USD',
#               'EOS/BTC',
#               'EOS/ETH',
#               'EOS/USD',
#               'ETC/BTC',
#               'ETC/USD',
#               'ETH/BTC',
#               'ETH/USD',
#               'ETP/BTC',
#               'ETP/ETH',
#               'ETP/USD',
#               'FUN/BTC',
#               'FUN/ETH',
#               'FUN/USD',
#               'GNT/BTC',
#               'GNT/ETH',
#               'GNT/USD',
#               'LTC/BTC',
#               'LTC/USD',
#               'NEO/BTC',
#               'NEO/ETH',
#               'NEO/USD',
#               'OMG/BTC',
#               'OMG/ETH',
#               'OMG/USD',
#               'QTUM/BTC',
#               'QTUM/ETH',
#               'QTUM/USD',
#               'RCN/BTC',
#               'RCN/ETH',
#               'RCN/USD',
#               'REP/BTC',
#               'REP/ETH',
#               'REP/USD',
#               'RLC/BTC',
#               'RLC/ETH',
#               'RLC/USD',
#               'SAN/BTC',
#               'SAN/ETH',
#               'SAN/USD',
#               'SNT/BTC',
#               'SNT/ETH',
#               'SNT/USD',
#               'SPK/BTC',
#               'SPK/ETH',
#               'SPK/USD',
#               'TNB/BTC',
#               'TNB/ETH',
#               'TNB/USD',
#               'TRX/BTC',
#               'TRX/ETH',
#               'TRX/USD',
#               'XMR/BTC',
#               'XMR/USD',
#               'XRP/BTC',
#               'XRP/USD',
#               'ZEC/BTC',
#               'ZEC/USD',
#               'ZRX/BTC',
#               'ZRX/ETH',
#               'ZRX/USD'},
#  'bitfinex2': {'AVT/BTC',
#                'AVT/ETH',
#                'AVT/USD',
#                'BCH/BTC',
#                'BCH/ETH',
#                'BCH/USD',
#                'BT2/BTC',
#                'BT2/USD',
#                'BTC/USD',
#                'BTG/BTC',
#                'BTG/USD',
#                'DASH/BTC',
#                'DASH/USD',
#                'DAT/BTC',
#                'DAT/ETH',
#                'DAT/USD',
#                'EDO/BTC',
#                'EDO/ETH',
#                'EDO/USD',
#                'EOS/BTC',
#                'EOS/ETH',
#                'EOS/USD',
#                'ETC/BTC',
#                'ETC/USD',
#                'ETH/BTC',
#                'ETH/USD',
#                'ETP/BTC',
#                'ETP/ETH',
#                'ETP/USD',
#                'LTC/BTC',
#                'LTC/USD',
#                'NEO/BTC',
#                'NEO/ETH',
#                'NEO/USD',
#                'OMG/BTC',
#                'OMG/ETH',
#                'OMG/USD',
#                'QTUM/BTC',
#                'QTUM/ETH',
#                'QTUM/USD',
#                'SAN/BTC',
#                'SAN/ETH',
#                'SAN/USD',
#                'XMR/BTC',
#                'XMR/USD',
#                'XRP/BTC',
#                'XRP/USD',
#                'ZEC/BTC',
#                'ZEC/USD'},
#  'bitflyer': {'BCH/BTC', 'ETH/BTC'},
#  'bithumb': set(),
#  'bitlish': {'BCH/BTC',
#              'BTC/USD',
#              'BTG/BTC',
#              'DASH/BTC',
#              'DASH/USD',
#              'DOGE/BTC',
#              'ETH/BTC',
#              'ETH/USD',
#              'LTC/BTC',
#              'LTC/USD',
#              'XMR/BTC',
#              'ZEC/BTC',
#              'ZEC/USD'},
#  'bitmarket': {'LTC/BTC'},
#  'bitmex': {'BTC/USD'},
#  'bitso': {'XRP/BTC', 'LTC/BTC', 'BCH/BTC', 'ETH/BTC'},
#  'bitstamp': {'BCH/BTC',
#               'BCH/USD',
#               'BTC/USD',
#               'ETH/BTC',
#               'ETH/USD',
#               'LTC/BTC',
#               'LTC/USD',
#               'XRP/BTC',
#               'XRP/USD'},
#  'bitstamp1': {'BTC/USD',
#                'ETH/BTC',
#                'ETH/USD',
#                'LTC/BTC',
#                'LTC/USD',
#                'XRP/BTC',
#                'XRP/USD'},
#  'bittrex': {'1ST/BTC',
#              '1ST/ETH',
#              '2GIVE/BTC',
#              'ABY/BTC',
#              'ADA/BTC',
#              'ADA/ETH',
#              'ADA/USDT',
#              'ADT/BTC',
#              'ADT/ETH',
#              'ADX/BTC',
#              'ADX/ETH',
#              'AEON/BTC',
#              'AGRS/BTC',
#              'AMP/BTC',
#              'ANT/BTC',
#              'ANT/ETH',
#              'ARDR/BTC',
#              'ARK/BTC',
#              'AUR/BTC',
#              'BAT/BTC',
#              'BAT/ETH',
#              'BAY/BTC',
#              'BCH/BTC',
#              'BCH/ETH',
#              'BCH/USDT',
#              'BCY/BTC',
#              'BITB/BTC',
#              'BLITZ/BTC',
#              'BLK/BTC',
#              'BLOCK/BTC',
#              'BNT/BTC',
#              'BNT/ETH',
#              'BRK/BTC',
#              'BRX/BTC',
#              'BSD/BTC',
#              'BTC/USDT',
#              'BTG/BTC',
#              'BTG/ETH',
#              'BTG/USDT',
#              'BURST/BTC',
#              'BYC/BTC',
#              'CANN/BTC',
#              'CFI/BTC',
#              'CFI/ETH',
#              'CLAM/BTC',
#              'CLOAK/BTC',
#              'CLUB/BTC',
#              'COVAL/BTC',
#              'CPC/BTC',
#              'CRB/BTC',
#              'CRB/ETH',
#              'CRW/BTC',
#              'CURE/BTC',
#              'CVC/BTC',
#              'CVC/ETH',
#              'DASH/BTC',
#              'DASH/ETH',
#              'DASH/USDT',
#              'DCR/BTC',
#              'DCT/BTC',
#              'DGB/BTC',
#              'DGB/ETH',
#              'DMD/BTC',
#              'DNT/BTC',
#              'DNT/ETH',
#              'DOGE/BTC',
#              'DOPE/BTC',
#              'DTB/BTC',
#              'DYN/BTC',
#              'EBST/BTC',
#              'EDG/BTC',
#              'EFL/BTC',
#              'EGC/BTC',
#              'EMC/BTC',
#              'EMC2/BTC',
#              'ENG/BTC',
#              'ENG/ETH',
#              'ENRG/BTC',
#              'ERC/BTC',
#              'ETC/BTC',
#              'ETC/ETH',
#              'ETC/USDT',
#              'ETH/BTC',
#              'ETH/USDT',
#              'EXCL/BTC',
#              'EXP/BTC',
#              'FAIR/BTC',
#              'FCT/BTC',
#              'FCT/ETH',
#              'FLDC/BTC',
#              'FLO/BTC',
#              'FTC/BTC',
#              'FUN/BTC',
#              'FUN/ETH',
#              'GAM/BTC',
#              'GAME/BTC',
#              'GBG/BTC',
#              'GBYTE/BTC',
#              'GCR/BTC',
#              'GLD/BTC',
#              'GNO/BTC',
#              'GNO/ETH',
#              'GNT/BTC',
#              'GNT/ETH',
#              'GOLOS/BTC',
#              'GRC/BTC',
#              'GRS/BTC',
#              'GUP/BTC',
#              'GUP/ETH',
#              'HMQ/BTC',
#              'HMQ/ETH',
#              'IGNIS/BTC',
#              'INCNT/BTC',
#              'INFX/BTC',
#              'IOC/BTC',
#              'ION/BTC',
#              'IOP/BTC',
#              'KMD/BTC',
#              'KORE/BTC',
#              'LBC/BTC',
#              'LGD/BTC',
#              'LGD/ETH',
#              'LMC/BTC',
#              'LSK/BTC',
#              'LTC/BTC',
#              'LTC/ETH',
#              'LTC/USDT',
#              'LUN/BTC',
#              'LUN/ETH',
#              'MAID/BTC',
#              'MANA/BTC',
#              'MANA/ETH',
#              'MCO/BTC',
#              'MCO/ETH',
#              'MEME/BTC',
#              'MER/BTC',
#              'MLN/BTC',
#              'MONA/BTC',
#              'MUE/BTC',
#              'MUSIC/BTC',
#              'NAV/BTC',
#              'NEO/BTC',
#              'NEO/ETH',
#              'NEO/USDT',
#              'NEOS/BTC',
#              'NLG/BTC',
#              'NMR/BTC',
#              'NMR/ETH',
#              'NXC/BTC',
#              'NXS/BTC',
#              'NXT/BTC',
#              'NXT/USDT',
#              'OK/BTC',
#              'OMG/BTC',
#              'OMG/ETH',
#              'OMG/USDT',
#              'OMNI/BTC',
#              'PART/BTC',
#              'PAY/BTC',
#              'PAY/ETH',
#              'PDC/BTC',
#              'PINK/BTC',
#              'PIVX/BTC',
#              'PKB/BTC',
#              'POT/BTC',
#              'POWR/BTC',
#              'POWR/ETH',
#              'PPC/BTC',
#              'PTC/BTC',
#              'PTOY/BTC',
#              'PTOY/ETH',
#              'QRL/BTC',
#              'QRL/ETH',
#              'QTUM/BTC',
#              'QTUM/ETH',
#              'QWARK/BTC',
#              'RADS/BTC',
#              'RBY/BTC',
#              'RCN/BTC',
#              'RCN/ETH',
#              'RDD/BTC',
#              'REP/BTC',
#              'REP/ETH',
#              'RISE/BTC',
#              'RLC/BTC',
#              'RLC/ETH',
#              'SALT/BTC',
#              'SALT/ETH',
#              'SBD/BTC',
#              'SC/BTC',
#              'SC/ETH',
#              'SEQ/BTC',
#              'SHIFT/BTC',
#              'SIB/BTC',
#              'SLR/BTC',
#              'SLS/BTC',
#              'SNRG/BTC',
#              'SNT/BTC',
#              'SNT/ETH',
#              'SPHR/BTC',
#              'SPR/BTC',
#              'START/BTC',
#              'STEEM/BTC',
#              'STORJ/BTC',
#              'STORJ/ETH',
#              'STRAT/BTC',
#              'STRAT/ETH',
#              'SWT/BTC',
#              'SYNX/BTC',
#              'SYS/BTC',
#              'THC/BTC',
#              'TIX/BTC',
#              'TIX/ETH',
#              'TKS/BTC',
#              'TRST/BTC',
#              'TRST/ETH',
#              'TRUST/BTC',
#              'TX/BTC',
#              'UBQ/BTC',
#              'UKG/BTC',
#              'UKG/ETH',
#              'UNB/BTC',
#              'VIA/BTC',
#              'VIB/BTC',
#              'VIB/ETH',
#              'VOX/BTC',
#              'VRC/BTC',
#              'VRM/BTC',
#              'VTC/BTC',
#              'VTR/BTC',
#              'WAVES/BTC',
#              'WAVES/ETH',
#              'WINGS/BTC',
#              'WINGS/ETH',
#              'XCP/BTC',
#              'XDN/BTC',
#              'XEL/BTC',
#              'XEM/BTC',
#              'XEM/ETH',
#              'XLM/BTC',
#              'XLM/ETH',
#              'XMG/BTC',
#              'XMR/BTC',
#              'XMR/ETH',
#              'XMR/USDT',
#              'XMY/BTC',
#              'XRP/BTC',
#              'XRP/ETH',
#              'XRP/USDT',
#              'XST/BTC',
#              'XVC/BTC',
#              'XVG/BTC',
#              'XVG/USDT',
#              'XWC/BTC',
#              'XZC/BTC',
#              'ZCL/BTC',
#              'ZEC/BTC',
#              'ZEC/ETH',
#              'ZEC/USDT',
#              'ZEN/BTC'},
#  'bl3p': set(),
#  'bleutrade': {'ADC/BTC',
#                'ADC/DOGE',
#                'ADC/ETH',
#                'BCH/BTC',
#                'BCH/DOGE',
#                'BCH/ETH',
#                'BITB/BTC',
#                'BITB/DOGE',
#                'BITB/ETH',
#                'BLK/BTC',
#                'BLK/DOGE',
#                'BLK/ETH',
#                'BSTY/BTC',
#                'BSTY/DOGE',
#                'BSTY/ETH',
#                'BTA/BTC',
#                'BTA/DOGE',
#                'BTA/ETH',
#                'BTC/DOGE',
#                'BTC/ETH',
#                'BTCD/BTC',
#                'BTCD/DOGE',
#                'BTCD/ETH',
#                'BTG/BTC',
#                'BTG/DOGE',
#                'BTG/ETH',
#                'CDN/BTC',
#                'CDN/DOGE',
#                'CDN/ETH',
#                'CLAM/BTC',
#                'CLAM/DOGE',
#                'CLAM/ETH',
#                'DASH/BTC',
#                'DASH/DOGE',
#                'DASH/ETH',
#                'DCR/BTC',
#                'DCR/DOGE',
#                'DCR/ETH',
#                'DGC/BTC',
#                'DGC/DOGE',
#                'DGC/ETH',
#                'DOGE/BTC',
#                'DOGE/ETH',
#                'DP/BTC',
#                'DP/DOGE',
#                'DP/ETH',
#                'EFL/BTC',
#                'EFL/DOGE',
#                'EFL/ETH',
#                'ETH/BTC',
#                'ETH/DOGE',
#                'EXP/BTC',
#                'EXP/DOGE',
#                'EXP/ETH',
#                'FJC/BTC',
#                'FJC/DOGE',
#                'FJC/ETH',
#                'GB/BTC',
#                'GB/DOGE',
#                'GB/ETH',
#                'HTML/BTC',
#                'HTML/DOGE',
#                'HTML/ETH',
#                'LTC/BTC',
#                'LTC/DOGE',
#                'LTC/ETH',
#                'MONA/BTC',
#                'MONA/DOGE',
#                'MONA/ETH',
#                'MOON/BTC',
#                'MOON/DOGE',
#                'MOON/ETH',
#                'NEOS/BTC',
#                'NEOS/DOGE',
#                'NEOS/ETH',
#                'NLG/BTC',
#                'NLG/DOGE',
#                'NLG/ETH',
#                'NMC/BTC',
#                'NMC/DOGE',
#                'NMC/ETH',
#                'NVC/BTC',
#                'NVC/DOGE',
#                'NVC/ETH',
#                'OK/BTC',
#                'OK/DOGE',
#                'OK/ETH',
#                'POT/BTC',
#                'POT/DOGE',
#                'POT/ETH',
#                'PPC/BTC',
#                'PPC/DOGE',
#                'PPC/ETH',
#                'QTUM/BTC',
#                'QTUM/DOGE',
#                'QTUM/ETH',
#                'RDD/BTC',
#                'RDD/DOGE',
#                'RDD/ETH',
#                'SLG/BTC',
#                'SLG/DOGE',
#                'SLG/ETH',
#                'SLR/BTC',
#                'SLR/DOGE',
#                'SLR/ETH',
#                'START/BTC',
#                'START/DOGE',
#                'START/ETH',
#                'TROLL/BTC',
#                'TROLL/DOGE',
#                'TROLL/ETH',
#                'UNO/BTC',
#                'UNO/DOGE',
#                'UNO/ETH',
#                'VRC/BTC',
#                'VRC/DOGE',
#                'VRC/ETH',
#                'VTC/BTC',
#                'VTC/DOGE',
#                'VTC/ETH',
#                'WDC/BTC',
#                'WDC/DOGE',
#                'WDC/ETH',
#                'XPM/BTC',
#                'XPM/DOGE',
#                'XPM/ETH',
#                'XVP/BTC',
#                'XVP/DOGE',
#                'XVP/ETH',
#                'ZET/BTC',
#                'ZET/DOGE',
#                'ZET/ETH'},
#  'btcbox': set(),
#  'btcchina': {'LTC/BTC'},
#  'btcexchange': {'ETH/BTC'},
#  'btcmarkets': {'ETH/BTC', 'ETC/BTC', 'LTC/BTC', 'XRP/BTC', 'BCH/BTC'},
#  'btctradeua': {'PPC/BTC', 'LTC/BTC', 'NVC/BTC', 'DOGE/BTC', 'DASH/BTC'},
#  'btcturk': {'ETH/BTC'},
#  'btcx': {'BTC/USD'},
#  'bxinth': {'DOGE/BTC',
#             'ETH/BTC',
#             'FTC/BTC',
#             'HYP/BTC',
#             'LEO/BTC',
#             'LTC/BTC',
#             'NMC/BTC',
#             'PND/BTC',
#             'PPC/BTC',
#             'QRK/BTC',
#             'XCN/BTC',
#             'XPM/BTC',
#             'XPY/BTC',
#             'ZEC/BTC',
#             'ZET/BTC'},
#  'ccex': {'611/BTC',
#           '611/DOGE',
#           '611/LTC',
#           '611/USD',
#           'ABC/BTC',
#           'ABC/DOGE',
#           'ABC/LTC',
#           'ABC/USD',
#           'ACP/BTC',
#           'ACP/DOGE',
#           'ACP/LTC',
#           'ACP/USD',
#           'ADCN/BTC',
#           'ADCN/DOGE',
#           'ADCN/LTC',
#           'ADCN/USD',
#           'ADL/BTC',
#           'ADL/DOGE',
#           'ADL/LTC',
#           'ADL/USD',
#           'AIB/BTC',
#           'AIB/DOGE',
#           'AIB/LTC',
#           'AIB/USD',
#           'ALT/BTC',
#           'ALT/DOGE',
#           'ALT/LTC',
#           'ALT/USD',
#           'APC/BTC',
#           'APC/DOGE',
#           'APC/LTC',
#           'APC/USD',
#           'APW/BTC',
#           'APW/DOGE',
#           'APW/LTC',
#           'APW/USD',
#           'ARC/BTC',
#           'ARC/DOGE',
#           'ARC/LTC',
#           'ARC/USD',
#           'BASH/BTC',
#           'BASH/DOGE',
#           'BASH/LTC',
#           'BASH/USD',
#           'BAY/BTC',
#           'BAY/DOGE',
#           'BAY/LTC',
#           'BAY/USD',
#           'BBP/BTC',
#           'BBP/DOGE',
#           'BBP/LTC',
#           'BBP/USD',
#           'BDL/BTC',
#           'BDL/DOGE',
#           'BDL/LTC',
#           'BDL/USD',
#           'BITCF/BTC',
#           'BITCF/DOGE',
#           'BITCF/LTC',
#           'BITCF/USD',
#           'BQ/BTC',
#           'BQ/DOGE',
#           'BQ/LTC',
#           'BQ/USD',
#           'BRIT/BTC',
#           'BRIT/DOGE',
#           'BRIT/LTC',
#           'BRIT/USD',
#           'BTCS/BTC',
#           'BTCS/DOGE',
#           'BTCS/LTC',
#           'BTCS/USD',
#           'BTCZ/BTC',
#           'BTCZ/DOGE',
#           'BTCZ/LTC',
#           'BTCZ/USD',
#           'BTQ/BTC',
#           'BTQ/DOGE',
#           'BTQ/LTC',
#           'BTQ/USD',
#           'BURST/BTC',
#           'BURST/DOGE',
#           'BURST/LTC',
#           'BURST/USD',
#           'CALC/BTC',
#           'CALC/DOGE',
#           'CALC/LTC',
#           'CALC/USD',
#           'CCRB/BTC',
#           'CCRB/DOGE',
#           'CCRB/LTC',
#           'CCRB/USD',
#           'CESC/BTC',
#           'CESC/DOGE',
#           'CESC/LTC',
#           'CESC/USD',
#           'CJ/BTC',
#           'CJ/DOGE',
#           'CJ/LTC',
#           'CJ/USD',
#           'CRC/BTC',
#           'CRC/DOGE',
#           'CRC/LTC',
#           'CRC/USD',
#           'CRW/BTC',
#           'CRW/DOGE',
#           'CRW/LTC',
#           'CRW/USD',
#           'CTIC3/BTC',
#           'CTIC3/DOGE',
#           'CTIC3/LTC',
#           'CTIC3/USD',
#           'CTO/BTC',
#           'CTO/DOGE',
#           'CTO/LTC',
#           'CTO/USD',
#           'DASH/BTC',
#           'DASH/DOGE',
#           'DASH/LTC',
#           'DASH/USD',
#           'DEUS/BTC',
#           'DEUS/DOGE',
#           'DEUS/LTC',
#           'DEUS/USD',
#           'DOGE/BTC',
#           'DOGE/LTC',
#           'DOGE/USD',
#           'EAG/BTC',
#           'EAG/DOGE',
#           'EAG/LTC',
#           'EAG/USD',
#           'ECN/BTC',
#           'ECN/DOGE',
#           'ECN/LTC',
#           'ECN/USD',
#           'EL/BTC',
#           'EL/DOGE',
#           'EL/LTC',
#           'EL/USD',
#           'ETC/BTC',
#           'ETC/DOGE',
#           'ETC/LTC',
#           'ETC/USD',
#           'ETH/BTC',
#           'ETH/DOGE',
#           'ETH/LTC',
#           'ETH/USD',
#           'ETT/BTC',
#           'ETT/DOGE',
#           'ETT/LTC',
#           'ETT/USD',
#           'EVR/BTC',
#           'EVR/DOGE',
#           'EVR/LTC',
#           'EVR/USD',
#           'FUTC/BTC',
#           'FUTC/DOGE',
#           'FUTC/LTC',
#           'FUTC/USD',
#           'GARY/BTC',
#           'GARY/DOGE',
#           'GARY/LTC',
#           'GARY/USD',
#           'GBC/BTC',
#           'GBC/DOGE',
#           'GBC/LTC',
#           'GBC/USD',
#           'GLD/BTC',
#           'GLD/DOGE',
#           'GLD/LTC',
#           'GLD/USD',
#           'GMX/BTC',
#           'GMX/DOGE',
#           'GMX/LTC',
#           'GMX/USD',
#           'GRC/BTC',
#           'GRC/DOGE',
#           'GRC/LTC',
#           'GRC/USD',
#           'GRS/BTC',
#           'GRS/DOGE',
#           'GRS/LTC',
#           'GRS/USD',
#           'GRWI/BTC',
#           'GRWI/DOGE',
#           'GRWI/LTC',
#           'GRWI/USD',
#           'GUC/BTC',
#           'GUC/DOGE',
#           'GUC/LTC',
#           'GUC/USD',
#           'HEAT/BTC',
#           'HEAT/DOGE',
#           'HEAT/LTC',
#           'HEAT/USD',
#           'HSR/BTC',
#           'HSR/DOGE',
#           'HSR/LTC',
#           'HSR/USD',
#           'IOP/BTC',
#           'IOP/DOGE',
#           'IOP/LTC',
#           'IOP/USD',
#           'KLC/BTC',
#           'KLC/DOGE',
#           'KLC/LTC',
#           'KLC/USD',
#           'KRONE/BTC',
#           'KRONE/DOGE',
#           'KRONE/LTC',
#           'KRONE/USD',
#           'LDCN/BTC',
#           'LDCN/DOGE',
#           'LDCN/LTC',
#           'LDCN/USD',
#           'LEO/BTC',
#           'LEO/DOGE',
#           'LEO/LTC',
#           'LEO/USD',
#           'LINDA/BTC',
#           'LINDA/DOGE',
#           'LINDA/LTC',
#           'LINDA/USD',
#           'LOG/BTC',
#           'LOG/DOGE',
#           'LOG/LTC',
#           'LOG/USD',
#           'LTC/BTC',
#           'LTC/USD',
#           'LTCR/BTC',
#           'LTCR/DOGE',
#           'LTCR/LTC',
#           'LTCR/USD',
#           'LUX/BTC',
#           'LUX/DOGE',
#           'LUX/LTC',
#           'LUX/USD',
#           'MBL/BTC',
#           'MBL/DOGE',
#           'MBL/LTC',
#           'MBL/USD',
#           'MCAP/BTC',
#           'MCAP/DOGE',
#           'MCAP/LTC',
#           'MCAP/USD',
#           'MCR/BTC',
#           'MCR/DOGE',
#           'MCR/LTC',
#           'MCR/USD',
#           'MEN/BTC',
#           'MEN/DOGE',
#           'MEN/LTC',
#           'MEN/USD',
#           'MOIN/BTC',
#           'MOIN/DOGE',
#           'MOIN/LTC',
#           'MOIN/USD',
#           'NAMO/BTC',
#           'NAMO/DOGE',
#           'NAMO/LTC',
#           'NAMO/USD',
#           'NDC/BTC',
#           'NDC/DOGE',
#           'NDC/LTC',
#           'NDC/USD',
#           'NEWB/BTC',
#           'NEWB/DOGE',
#           'NEWB/LTC',
#           'NEWB/USD',
#           'NLC2/BTC',
#           'NLC2/DOGE',
#           'NLC2/LTC',
#           'NLC2/USD',
#           'NOTE/BTC',
#           'NOTE/DOGE',
#           'NOTE/LTC',
#           'NOTE/USD',
#           'NVC/BTC',
#           'NVC/DOGE',
#           'NVC/LTC',
#           'NVC/USD',
#           'NXT/BTC',
#           'NXT/DOGE',
#           'NXT/LTC',
#           'NXT/USD',
#           'ODN/BTC',
#           'ODN/DOGE',
#           'ODN/LTC',
#           'ODN/USD',
#           'OMNI/BTC',
#           'OMNI/DOGE',
#           'OMNI/LTC',
#           'OMNI/USD',
#           'ORME/BTC',
#           'ORME/DOGE',
#           'ORME/LTC',
#           'ORME/USD',
#           'OTX/BTC',
#           'OTX/DOGE',
#           'OTX/LTC',
#           'OTX/USD',
#           'OX/BTC',
#           'OX/DOGE',
#           'OX/LTC',
#           'OX/USD',
#           'PCS/BTC',
#           'PCS/DOGE',
#           'PCS/LTC',
#           'PCS/USD',
#           'PIZZA/BTC',
#           'PIZZA/DOGE',
#           'PIZZA/LTC',
#           'PIZZA/USD',
#           'POLY/BTC',
#           'POLY/DOGE',
#           'POLY/LTC',
#           'POLY/USD',
#           'PRC/BTC',
#           'PRC/DOGE',
#           'PRC/LTC',
#           'PRC/USD',
#           'PRES/BTC',
#           'PRES/DOGE',
#           'PRES/LTC',
#           'PRES/USD',
#           'PROC/BTC',
#           'PROC/DOGE',
#           'PROC/LTC',
#           'PROC/USD',
#           'PURA/BTC',
#           'PURA/DOGE',
#           'PURA/LTC',
#           'PURA/USD',
#           'R/BTC',
#           'R/DOGE',
#           'R/LTC',
#           'R/USD',
#           'RBIES/BTC',
#           'RBIES/DOGE',
#           'RBIES/LTC',
#           'RBIES/USD',
#           'RHFC/BTC',
#           'RHFC/DOGE',
#           'RHFC/LTC',
#           'RHFC/USD',
#           'RIYA/BTC',
#           'RIYA/DOGE',
#           'RIYA/LTC',
#           'RIYA/USD',
#           'RKC/BTC',
#           'RKC/DOGE',
#           'RKC/LTC',
#           'RKC/USD',
#           'SBC/BTC',
#           'SBC/DOGE',
#           'SBC/LTC',
#           'SBC/USD',
#           'SIB/BTC',
#           'SIB/DOGE',
#           'SIB/LTC',
#           'SIB/USD',
#           'SMLY/BTC',
#           'SMLY/DOGE',
#           'SMLY/LTC',
#           'SMLY/USD',
#           'TCOIN/BTC',
#           'TCOIN/DOGE',
#           'TCOIN/LTC',
#           'TCOIN/USD',
#           'TERA/BTC',
#           'TERA/DOGE',
#           'TERA/LTC',
#           'TERA/USD',
#           'TESLA/BTC',
#           'TESLA/DOGE',
#           'TESLA/LTC',
#           'TESLA/USD',
#           'TOA/BTC',
#           'TOA/DOGE',
#           'TOA/LTC',
#           'TOA/USD',
#           'TRC/BTC',
#           'TRC/DOGE',
#           'TRC/LTC',
#           'TRC/USD',
#           'TRUMP/BTC',
#           'TRUMP/DOGE',
#           'TRUMP/LTC',
#           'TRUMP/USD',
#           'UNO/BTC',
#           'UNO/DOGE',
#           'UNO/LTC',
#           'UNO/USD',
#           'UNY/BTC',
#           'UNY/DOGE',
#           'UNY/LTC',
#           'UNY/USD',
#           'USD/BTC',
#           'USDT/BTC',
#           'USDT/DOGE',
#           'USDT/LTC',
#           'USDT/USD',
#           'UTA/BTC',
#           'UTA/DOGE',
#           'UTA/LTC',
#           'UTA/USD',
#           'VRS/BTC',
#           'VRS/DOGE',
#           'VRS/LTC',
#           'VRS/USD',
#           'VSX/BTC',
#           'VSX/DOGE',
#           'VSX/LTC',
#           'VSX/USD',
#           'VUC/BTC',
#           'VUC/DOGE',
#           'VUC/LTC',
#           'VUC/USD',
#           'WA/BTC',
#           'WA/DOGE',
#           'WA/LTC',
#           'WA/USD',
#           'XAUR/BTC',
#           'XAUR/DOGE',
#           'XAUR/LTC',
#           'XAUR/USD',
#           'XBY/BTC',
#           'XBY/DOGE',
#           'XBY/LTC',
#           'XBY/USD',
#           'XCXT/BTC',
#           'XCXT/DOGE',
#           'XCXT/LTC',
#           'XCXT/USD',
#           'XHI/BTC',
#           'XHI/DOGE',
#           'XHI/LTC',
#           'XHI/USD',
#           'XOT/BTC',
#           'XOT/DOGE',
#           'XOT/LTC',
#           'XOT/USD',
#           'XTO/BTC',
#           'XTO/DOGE',
#           'XTO/LTC',
#           'XTO/USD',
#           'YOC/BTC',
#           'YOC/DOGE',
#           'YOC/LTC',
#           'YOC/USD',
#           'ZEC/BTC',
#           'ZEC/DOGE',
#           'ZEC/LTC',
#           'ZEC/USD',
#           'ZENI/BTC',
#           'ZENI/DOGE',
#           'ZENI/LTC',
#           'ZENI/USD',
#           'ZNY/BTC',
#           'ZNY/DOGE',
#           'ZNY/LTC',
#           'ZNY/USD',
#           'ZSC/BTC',
#           'ZSC/DOGE',
#           'ZSC/LTC',
#           'ZSC/USD',
#           'ZZC/BTC',
#           'ZZC/DOGE',
#           'ZZC/LTC',
#           'ZZC/USD'},
#  'cex': {'BCH/BTC',
#          'BCH/USD',
#          'BTC/USD',
#          'BTG/BTC',
#          'BTG/USD',
#          'DASH/BTC',
#          'DASH/USD',
#          'ETH/BTC',
#          'ETH/USD',
#          'XLM/BTC',
#          'XLM/USD',
#          'XRP/BTC',
#          'XRP/USD',
#          'ZEC/BTC',
#          'ZEC/USD'},
#  'chbtc': set(),
#  'chilebit': set(),
#  'coincheck': set(),
#  'coinexchange': {'1337/BTC',
#                   '1337/DOGE',
#                   '611/BTC',
#                   'ACC/BTC',
#                   'ACES/BTC',
#                   'ACP/BTC',
#                   'ADCN/BTC',
#                   'ADST/BTC',
#                   'ADST/ETH',
#                   'ADZ/BTC',
#                   'AI/BTC',
#                   'AI/ETH',
#                   'AKY/BTC',
#                   'ALIS/BTC',
#                   'ALIS/ETH',
#                   'ALL/BTC',
#                   'ALTC/BTC',
#                   'AMMO/BTC',
#                   'AMS/BTC',
#                   'ANI/BTC',
#                   'ANTX/BTC',
#                   'ARG/BTC',
#                   'ARGUS/BTC',
#                   'ASN/BTC',
#                   'ATOM/BTC',
#                   'ATX/BTC',
#                   'AU/BTC',
#                   'B2B/BTC',
#                   'BCC/BTC',
#                   'BCH/BTC',
#                   'BDL/BTC',
#                   'BELA/BTC',
#                   'BENJI/BTC',
#                   'BET/BTC',
#                   'BIGUP/BTC',
#                   'BIGUP/DOGE',
#                   'BIRDS/BTC',
#                   'BITB/BTC',
#                   'BITB/DOGE',
#                   'BITB/ETH',
#                   'BITZ/BTC',
#                   'BLAS/BTC',
#                   'BLAS/DOGE',
#                   'BLAS/ETC',
#                   'BLAS/ETH',
#                   'BLAS/LTC',
#                   'BLAZR/BTC',
#                   'BLK/BTC',
#                   'BLN/BTC',
#                   'BLN/ETH',
#                   'BLU/BTC',
#                   'BLUE/BTC',
#                   'BLUE/ETH',
#                   'BOAT/BTC',
#                   'BON/BTC',
#                   'BQ/BTC',
#                   'BQ/ETH',
#                   'BRAT/BTC',
#                   'BRIT/BTC',
#                   'BSN/BTC',
#                   'BSR/BTC',
#                   'BTBc/BTC',
#                   'BTCRED/BTC',
#                   'BTDX/BTC',
#                   'BTE/BTC',
#                   'BTE/ETH',
#                   'BTPL/BTC',
#                   'BUZZ/BTC',
#                   'BXT/BTC',
#                   'CAB/BTC',
#                   'CACH/BTC',
#                   'CALC/BTC',
#                   'CANN/BTC',
#                   'CC/BTC',
#                   'CDX/BTC',
#                   'CDX/ETH',
#                   'CHEAP/BTC',
#                   'CHESS/BTC',
#                   'CHIPS/BTC',
#                   'CJ/BTC',
#                   'CLD/BTC',
#                   'CLD/ETH',
#                   'CMPCO/BTC',
#                   'CMT/BTC',
#                   'CNNC/BTC',
#                   'COUPE/BTC',
#                   'COUPE/ETC',
#                   'COXST/BTC',
#                   'CRAVE/BTC',
#                   'CRAVE/DOGE',
#                   'CRAVE/ETH',
#                   'CRAVE/LTC',
#                   'CRDNC/BTC',
#                   'CREA/BTC',
#                   'CREA/ETH',
#                   'CRW/BTC',
#                   'CTIC2/BTC',
#                   'CUBE/BTC',
#                   'CXT/BTC',
#                   'CYDER/BTC',
#                   'DALC/BTC',
#                   'DALC/ETH',
#                   'DASH/BTC',
#                   'DASH/ETH',
#                   'DAV/BTC',
#                   'DCN/BTC',
#                   'DCN/ETH',
#                   'DEM/BTC',
#                   'DFS/BTC',
#                   'DFS/ETH',
#                   'DFS/LTC',
#                   'DGB/BTC',
#                   'DGC/BTC',
#                   'DIME/BTC',
#                   'DIME/DOGE',
#                   'DLC/BTC',
#                   'DMB/BTC',
#                   'DMC/BTC',
#                   'DNR/BTC',
#                   'DNR/ETH',
#                   'DOGE/BTC',
#                   'DOGE/ETC',
#                   'DOGE/LTC',
#                   'DOLLAR/BTC',
#                   'DP/BTC',
#                   'DRGN/BTC',
#                   'DRGN/ETH',
#                   'DRS/BTC',
#                   'DSR/BTC',
#                   'DUTCH/BTC',
#                   'EBT/BTC',
#                   'EBTC/BTC',
#                   'EBTC/ETH',
#                   'ECC/BTC',
#                   'ECN/BTC',
#                   'ECN/LTC',
#                   'EDRC/BTC',
#                   'EGC/BTC',
#                   'ELIX/BTC',
#                   'ELIX/ETH',
#                   'ELS/BTC',
#                   'EMC/BTC',
#                   'EQL/BTC',
#                   'EQL/ETH',
#                   'EQT/BTC',
#                   'ERY/BTC',
#                   'ESP/BTC',
#                   'ETBS/BTC',
#                   'ETBS/ETH',
#                   'ETC/BTC',
#                   'ETC/ETH',
#                   'ETG/BTC',
#                   'ETG/ETH',
#                   'ETH/BTC',
#                   'ETHD/BTC',
#                   'ETHD/ETH',
#                   'ETHD/LTC',
#                   'ETHOS/BTC',
#                   'ETHOS/ETH',
#                   'ETN/BTC',
#                   'EXCL/BTC',
#                   'FAIR/BTC',
#                   'FAP/BTC',
#                   'FAP/ETH',
#                   'FAZZ/BTC',
#                   'FLASH/BTC',
#                   'FLIK/BTC',
#                   'FLIK/ETH',
#                   'FTC/BTC',
#                   'FXE/BTC',
#                   'FXE/ETH',
#                   'GAIN/BTC',
#                   'GAM/BTC',
#                   'GAM/ETH',
#                   'GB/BTC',
#                   'GBX/BTC',
#                   'GDC/BTC',
#                   'GEERT/BTC',
#                   'GET/BTC',
#                   'GLS/BTC',
#                   'GLT/BTC',
#                   'GLT/DOGE',
#                   'GMX/BTC',
#                   'GOLF/BTC',
#                   'GOOD/BTC',
#                   'GOOD/DOGE',
#                   'GOOD/ETH',
#                   'GP/BTC',
#                   'GP/ETC',
#                   'GRE/BTC',
#                   'GRS/BTC',
#                   'GRS/ETH',
#                   'GRX/BTC',
#                   'GRX/ETH',
#                   'GTC/BTC',
#                   'HAL/BTC',
#                   'HALLO/BTC',
#                   'HALLO/DOGE',
#                   'HBC/BTC',
#                   'HBC/ETH',
#                   'HC/BTC',
#                   'HIGH/BTC',
#                   'HMC/BTC',
#                   'HNC/BTC',
#                   'HODL/BTC',
#                   'HONEY/BTC',
#                   'HONEY/DOGE',
#                   'HONEY/ETC',
#                   'HONEY/ETH',
#                   'HONEY/LTC',
#                   'HPC/BTC',
#                   'HVCO/BTC',
#                   'HYP/BTC',
#                   'HYPER/BTC',
#                   'ICE/BTC',
#                   'IFT/BTC',
#                   'IMX/BTC',
#                   'INDIA/BTC',
#                   'INSN/BTC',
#                   'INXT/BTC',
#                   'INXT/ETH',
#                   'IQT/BTC',
#                   'IQT/ETH',
#                   'IXC/BTC',
#                   'JET/BTC',
#                   'JET/ETH',
#                   'JIN/BTC',
#                   'KAYI/BTC',
#                   'KAYI/DOGE',
#                   'KAYI/ETH',
#                   'KB3/BTC',
#                   'KLC/BTC',
#                   'KMD/BTC',
#                   'KMD/ETH',
#                   'KOBO/BTC',
#                   'KURT/BTC',
#                   'LA/BTC',
#                   'LA/ETH',
#                   'LCT/BTC',
#                   'LCT/ETH',
#                   'LIFE/BTC',
#                   'LINDA/BTC',
#                   'LINX/BTC',
#                   'LMC/BTC',
#                   'LNK/BTC',
#                   'LRC/BTC',
#                   'LRC/ETH',
#                   'LTC/BTC',
#                   'LTC/DOGE',
#                   'LTG/BTC',
#                   'LTG/ETH',
#                   'LUNA/BTC',
#                   'LVPS/BTC',
#                   'LVPS/ETC',
#                   'LVPS/ETH',
#                   'MAC/BTC',
#                   'MAG/BTC',
#                   'MARS/BTC',
#                   'MAY/BTC',
#                   'MEC/BTC',
#                   'MEME/BTC',
#                   'MER/BTC',
#                   'MGM/BTC',
#                   'MILO/BTC',
#                   'MINEX/BTC',
#                   'MINEX/ETH',
#                   'MINT/BTC',
#                   'MNM/BTC',
#                   'MNX/BTC',
#                   'MOIN/BTC',
#                   'MOJO/BTC',
#                   'MOON/BTC',
#                   'MOON/DOGE',
#                   'MOON/LTC',
#                   'MSCN/BTC',
#                   'MSP/BTC',
#                   'MSP/ETH',
#                   'MST/BTC',
#                   'MTH/BTC',
#                   'MTH/ETH',
#                   'MUE/BTC',
#                   'MXT/BTC',
#                   'MYB/BTC',
#                   'NBIT/BTC',
#                   'NEOG/BTC',
#                   'NEOG/ETH',
#                   'NLC2/BTC',
#                   'NLG/BTC',
#                   'NRO/BTC',
#                   'NTC/BTC',
#                   'NTC/ETH',
#                   'NTO/BTC',
#                   'NTO/ETH',
#                   'NUMUS/BTC',
#                   'OC/BTC',
#                   'ORB/BTC',
#                   'OXY/BTC',
#                   'PCN/BTC',
#                   'PCN/DOGE',
#                   'PCS/BTC',
#                   'PDG/BTC',
#                   'PEC/BTC',
#                   'PGL/BTC',
#                   'PIE/BTC',
#                   'PIGGY/BTC',
#                   'PIVX/BTC',
#                   'PIVX/ETH',
#                   'PIX/BTC',
#                   'PIX/ETH',
#                   'PKT/BTC',
#                   'PLACO/BTC',
#                   'PLX/BTC',
#                   'PLX/ETH',
#                   'POS/BTC',
#                   'POS/ETH',
#                   'POST/BTC',
#                   'POSW/BTC',
#                   'POT/BTC',
#                   'PRE/BTC',
#                   'PRE/ETH',
#                   'PRIMU/BTC',
#                   'PRL/BTC',
#                   'PRL/ETH',
#                   'PRN/BTC',
#                   'PRN/ETH',
#                   'PRO/BTC',
#                   'PRX/BTC',
#                   'PULSE/BTC',
#                   'PURA/BTC',
#                   'PURA/ETH',
#                   'PURE/BTC',
#                   'PUT/BTC',
#                   'PUT/ETH',
#                   'PUT/LTC',
#                   'QRL/BTC',
#                   'QRL/ETH',
#                   'QTUM/BTC',
#                   'QTUM/ETH',
#                   'RAIN/BTC',
#                   'REC/BTC',
#                   'REC/ETH',
#                   'REGA/BTC',
#                   'REX/BTC',
#                   'REX/ETH',
#                   'RIYA/BTC',
#                   'RMC/BTC',
#                   'RMC/ETH',
#                   'RNS/BTC',
#                   'ROC/BTC',
#                   'ROOFS/BTC',
#                   'RUNNERS/BTC',
#                   'RUP/BTC',
#                   'SCL/BTC',
#                   'SCL/ETH',
#                   'SCORE/BTC',
#                   'SCT/BTC',
#                   'SFC/BTC',
#                   'SFE/BTC',
#                   'SGR/BTC',
#                   'SGR/ETH',
#                   'SHND/BTC',
#                   'SHND/DOGE',
#                   'SIC/BTC',
#                   'SISA/BTC',
#                   'SISA/ETH',
#                   'SKULL/BTC',
#                   'SLEVIN/BTC',
#                   'SLR/BTC',
#                   'SMART/BTC',
#                   'SMART/DOGE',
#                   'SMS/BTC',
#                   'SMS/ETH',
#                   'SPRTS/BTC',
#                   'SPRTS/DOGE',
#                   'SRC/BTC',
#                   'STARS/BTC',
#                   'STN/BTC',
#                   'STX/BTC',
#                   'STX/ETH',
#                   'SUPER/BTC',
#                   'SYNX/BTC',
#                   'SYS/BTC',
#                   'TAAS/BTC',
#                   'TCOIN/BTC',
#                   'TELL/BTC',
#                   'TELL/DOGE',
#                   'TER/BTC',
#                   'TER/ETH',
#                   'TER/LTC',
#                   'TGT/BTC',
#                   'TGT/ETH',
#                   'TIPS/BTC',
#                   'TIPS/DOGE',
#                   'TLE/BTC',
#                   'TOPAZ/BTC',
#                   'TOR/BTC',
#                   'TRC/BTC',
#                   'TSE/BTC',
#                   'TSE/DOGE',
#                   'TSTR/BTC',
#                   'TURBO/BTC',
#                   'UFO/BTC',
#                   'ULA/BTC',
#                   'UNIFY/BTC',
#                   'UNIT/BTC',
#                   'UNO/BTC',
#                   'UNO/ETH',
#                   'UQC/BTC',
#                   'UQC/ETH',
#                   'USC/BTC',
#                   'VC/BTC',
#                   'VIDZ/BTC',
#                   'VISIO/BTC',
#                   'VLTC/BTC',
#                   'VOISE/BTC',
#                   'VOISE/ETH',
#                   'VOX/BTC',
#                   'VOX/ETC',
#                   'VOX/LTC',
#                   'VSX/BTC',
#                   'WINK/BTC',
#                   'WOMEN/BTC',
#                   'WORM/BTC',
#                   'WOW/BTC',
#                   'WOW/DOGE',
#                   'XBC/BTC',
#                   'XBL/BTC',
#                   'XBL/ETH',
#                   'XBTS/BTC',
#                   'XCO/BTC',
#                   'XCS/BTC',
#                   'XCT/BTC',
#                   'XCXT/BTC',
#                   'XDE2/BTC',
#                   'XGOX/BTC',
#                   'XGOX/ETH',
#                   'XLR/BTC',
#                   'XMCC/BTC',
#                   'XMRG/BTC',
#                   'XMRG/ETH',
#                   'XP/BTC',
#                   'XP/DOGE',
#                   'XQN/BTC',
#                   'XSH/BTC',
#                   'XSH/DOGE',
#                   'XSH/ETH',
#                   'XSTC/BTC',
#                   'XTD/BTC',
#                   'XVE/BTC',
#                   'XZC/BTC',
#                   'YOC/BTC',
#                   'ZCG/BTC',
#                   'ZCG/ETH',
#                   'ZCL/BTC',
#                   'ZEC/BTC',
#                   'ZEIT/BTC',
#                   'ZEIT/DOGE',
#                   'ZEIT/ETC',
#                   'ZENI/BTC',
#                   'ZMC/BTC',
#                   'ZOI/BTC',
#                   'ZSE/BTC',
#                   'ZZC/BTC',
#                   'ZZC/ETH'},
#  'coinfloor': {'BTC/USD'},
#  'coingi': {'BTC/USD',
#             'DASH/BTC',
#             'DOGE/BTC',
#             'DOGE/USD',
#             'LTC/BTC',
#             'LTC/USD',
#             'NMC/BTC',
#             'PPC/BTC',
#             'PPC/USD',
#             'VTC/BTC'},
#  'coinmarketcap': {'$$$/CAD',
#                    '$$$/USD',
#                    '10MT/CAD',
#                    '10MT/USD',
#                    '1337/CAD',
#                    '1337/USD',
#                    '1ST/CAD',
#                    '1ST/USD',
#                    '2GIVE/CAD',
#                    '2GIVE/USD',
#                    '300/CAD',
#                    '300/USD',
#                    '42/CAD',
#                    '42/USD',
#                    '611/CAD',
#                    '611/USD',
#                    '808/CAD',
#                    '808/USD',
#                    '888/CAD',
#                    '888/USD',
#                    '8BIT/CAD',
#                    '8BIT/USD',
#                    'AAC/CAD',
#                    'AAC/USD',
# ...
#            'SIGT/USD',
#            'SIGT/WAVES',
#            'SKULL/BTC',
#            'SKULL/DOGE',
#            'SKULL/ETH',
#            'SKULL/USD',
#            'SKULL/WAVES',
#            'SLFI/BTC',
#            'SLFI/DOGE',
#            'SLFI/ETH',
#            'SLFI/USD',
#            'SLFI/WAVES',
#            'SLING/BTC',
#            'SLING/DOGE',
#            'SLING/ETH',
#            'SLING/USD',
#            'SLING/WAVES',
#            'SLS/BTC',
#            'SLS/DOGE',
#            'SLS/ETH',
#            'SLS/USD',
#            'SLS/WAVES',
#            'SMART/BTC',
#            'SMART/DOGE',
#            'SMART/ETH',
#            'SMART/USD',
#            'SMART/WAVES',
#            'SMC/BTC',
#            'SMC/DOGE',
#            'SMC/ETH',
#            'SMC/USD',
#            'SMC/WAVES',
#            'SMT/BTC',
#            'SMT/DOGE',
#            'SMT/ETH',
#            'SMT/USD',
#            'SMT/WAVES',
#            'SNC/BTC',
#            'SNC/DOGE',
#            'SNC/ETH',
#            'SNC/USD',
#            'SNC/WAVES',
#            'SNM/BTC',
#            'SNM/DOGE',
#            'SNM/ETH',
#            'SNM/USD',
#            'SNM/WAVES',
#            'SNRG/BTC',
#            'SNRG/DOGE',
#            'SNRG/ETH',
#            'SNRG/USD',
#            'SNRG/WAVES',
#            'SOCC/BTC',
#            'SOCC/DOGE',
#            'SOCC/ETH',
#            'SOCC/USD',
#            'SOCC/WAVES',
#            'SONG/BTC',
#            'SONG/DOGE',
#            'SONG/ETH',
#            'SONG/USD',
#            'SONG/WAVES',
#            'SPACE/BTC',
#            'SPACE/DOGE',
#            'SPACE/ETH',
#            'SPACE/USD',
#            'SPACE/WAVES',
#            'SPC/BTC',
#            'SPC/DOGE',
#            'SPC/ETH',
#            'SPC/USD',
#            'SPC/WAVES',
#            'SPEX/BTC',
#            'SPEX/DOGE',
#            'SPEX/ETH',
#            'SPEX/USD',
#            'SPEX/WAVES',
#            'SPHTX/BTC',
#            'SPHTX/DOGE',
#            'SPHTX/ETH',
#            'SPHTX/USD',
#            'SPHTX/WAVES',
#            'SPORT/BTC',
#            'SPORT/DOGE',
#            'SPORT/ETH',
#            'SPORT/USD',
#            'SPORT/WAVES',
#            'SPR/BTC',
#            'SPR/DOGE',
#            'SPR/ETH',
#            'SPR/USD',
#            'SPR/WAVES',
#            'SPT/BTC',
#            'SPT/DOGE',
#            'SPT/ETH',
#            'SPT/USD',
#            'SPT/WAVES',
#            'SSC/BTC',
#            'SSC/DOGE',
#            'SSC/ETH',
#            'SSC/USD',
#            'SSC/WAVES',
#            'STA/BTC',
#            'STA/DOGE',
#            'STA/ETH',
#            'STA/USD',
#            'STA/WAVES',
#            'STAR/BTC',
#            'STAR/DOGE',
#            'STAR/ETH',
#            'STAR/USD',
#            'STAR/WAVES',
#            'START/BTC',
#            'START/DOGE',
#            'START/ETH',
#            'START/USD',
#            'START/WAVES',
#            'STEPS/BTC',
#            'STEPS/DOGE',
#            'STEPS/ETH',
#            'STEPS/USD',
#            'STEPS/WAVES',
#            'STK/BTC',
#            'STK/DOGE',
#            'STK/ETH',
#            'STK/USD',
#            'STK/WAVES',
#            'STORJ/BTC',
#            'STORJ/DOGE',
#            'STORJ/ETH',
#            'STORJ/USD',
#            'STORJ/WAVES',
#            'STS/BTC',
#            'STS/DOGE',
#            'STS/ETH',
#            'STS/USD',
#            'STS/WAVES',
#            'STU/BTC',
#            'STU/DOGE',
#            'STU/ETH',
#            'STU/USD',
#            'STU/WAVES',
#            'STV/BTC',
#            'STV/DOGE',
#            'STV/ETH',
#            'STV/USD',
#            'STV/WAVES',
#            'SUB/BTC',
#            'SUB/DOGE',
#            'SUB/ETH',
#            'SUB/USD',
#            'SUB/WAVES',
#            'SUPER/BTC',
#            'SUPER/DOGE',
#            'SUPER/ETH',
#            'SUPER/USD',
#            'SUPER/WAVES',
#            'SWING/BTC',
#            'SWING/DOGE',
#            'SWING/ETH',
#            'SWING/USD',
#            'SWING/WAVES',
#            'SWT/BTC',
#            'SWT/DOGE',
#            'SWT/ETH',
#            'SWT/USD',
#            'SWT/WAVES',
#            'SXC/BTC',
#            'SXC/DOGE',
#            'SXC/ETH',
#            'SXC/USD',
#            'SXC/WAVES',
#            'SYNX/BTC',
#            'SYNX/DOGE',
#            'SYNX/ETH',
#            'SYNX/USD',
#            'SYNX/WAVES',
#            'SYS/BTC',
#            'SYS/DOGE',
#            'SYS/ETH',
#            'SYS/USD',
#            'SYS/WAVES',
#            'TAG/BTC',
#            'TAG/DOGE',
#            'TAG/ETH',
#            'TAG/USD',
#            'TAG/WAVES',
#            'TAGR/BTC',
#            'TAGR/DOGE',
#            'TAGR/ETH',
#            'TAGR/USD',
#            'TAGR/WAVES',
#            'TAJ/BTC',
#            'TAJ/DOGE',
#            'TAJ/ETH',
#            'TAJ/USD',
#            'TAJ/WAVES',
#            'TALK/BTC',
#            'TALK/DOGE',
#            'TALK/ETH',
#            'TALK/USD',
#            'TALK/WAVES',
#            'TBX/BTC',
#            'TBX/DOGE',
#            'TBX/ETH',
#            'TBX/USD',
#            'TBX/WAVES',
#            'TCR/BTC',
#            'TCR/DOGE',
#            'TCR/ETH',
#            'TCR/USD',
#            'TCR/WAVES',
#            'TEAM/BTC',
#            'TEAM/DOGE',
#            'TEAM/ETH',
#            'TEAM/USD',
#            'TEAM/WAVES',
#            'TEK/BTC',
#            'TEK/DOGE',
#            'TEK/ETH',
#            'TEK/USD',
#            'TEK/WAVES',
#            'TELL/BTC',
#            'TELL/DOGE',
#            'TELL/ETH',
#            'TELL/USD',
#            'TELL/WAVES',
#            'TES/BTC',
#            'TES/DOGE',
#            'TES/ETH',
#            'TES/USD',
#            'TES/WAVES',
#            'TFL/BTC',
#            'TFL/DOGE',
#            'TFL/ETH',
#            'TFL/USD',
#            'TFL/WAVES',
#            'TIME/BTC',
#            'TIME/DOGE',
#            'TIME/ETH',
#            'TIME/USD',
#            'TIME/WAVES',
#            'TIT/BTC',
#            'TIT/DOGE',
#            'TIT/ETH',
#            'TIT/USD',
#            'TIT/WAVES',
#            'TKN/BTC',
#            'TKN/DOGE',
#            'TKN/ETH',
#            'TKN/USD',
#            'TKN/WAVES',
#            'TLE/BTC',
#            'TLE/DOGE',
#            'TLE/ETH',
#            'TLE/USD',
#            'TLE/WAVES',
#            'TNT/BTC',
#            'TNT/DOGE',
#            'TNT/ETH',
#            'TNT/USD',
#            'TNT/WAVES',
#            'TODAY/BTC',
#            'TODAY/DOGE',
#            'TODAY/ETH',
#            'TODAY/USD',
#            'TODAY/WAVES',
#            'TOKC/BTC',
#            'TOKC/DOGE',
#            'TOKC/ETH',
#            'TOKC/USD',
#            'TOKC/WAVES',
#            'TRICK/BTC',
#            'TRICK/DOGE',
#            'TRICK/ETH',
#            'TRICK/USD',
#            'TRICK/WAVES',
#            'TRUMP/BTC',
#            'TRUMP/DOGE',
#            'TRUMP/ETH',
#            'TRUMP/USD',
#            'TRUMP/WAVES',
#            'TRX/BTC',
#            'TRX/DOGE',
#            'TRX/ETH',
#            'TRX/USD',
#            'TRX/WAVES',
#            'TSE/BTC',
#            'TSE/DOGE',
#            'TSE/ETH',
#            'TSE/USD',
#            'TSE/WAVES',
#            'TTC/BTC',
#            'TTC/DOGE',
#            'TTC/ETH',
#            'TTC/USD',
#            'TTC/WAVES',
#            'TX/BTC',
#            'TX/DOGE',
#            'TX/ETH',
#            'TX/USD',
#            'TX/WAVES',
#            'UBTC/BTC',
#            'UBTC/DOGE',
#            'UBTC/ETH',
#            'UBTC/USD',
#            'UBTC/WAVES',
#            'UIS/BTC',
#            'UIS/DOGE',
#            'UIS/ETH',
#            'UIS/USD',
#            'UIS/WAVES',
#            'UNI/BTC',
#            'UNI/DOGE',
#            'UNI/ETH',
#            'UNI/USD',
#            'UNI/WAVES',
#            'UNIFY/BTC',
#            'UNIFY/DOGE',
#            'UNIFY/ETH',
#            'UNIFY/USD',
#            'UNIFY/WAVES',
#            'UNIT/BTC',
#            'UNIT/DOGE',
#            'UNIT/ETH',
#            'UNIT/USD',
#            'UNIT/WAVES',
#            'UNITS/BTC',
#            'UNITS/DOGE',
#            'UNITS/ETH',
#            'UNITS/USD',
#            'UNITS/WAVES',
#            'URC/BTC',
#            'URC/DOGE',
#            'URC/ETH',
#            'URC/USD',
#            'URC/WAVES',
#            'URO/BTC',
#            'URO/DOGE',
#            'URO/ETH',
#            'URO/USD',
#            'URO/WAVES',
#            'USC/BTC',
#            'USC/DOGE',
#            'USC/ETH',
#            'USC/USD',
#            'USC/WAVES',
#            'VAL/BTC',
#            'VAL/DOGE',
#            'VAL/ETH',
#            'VAL/USD',
#            'VAL/WAVES',
#            'VEC2/BTC',
#            'VEC2/DOGE',
#            'VEC2/ETH',
#            'VEC2/USD',
#            'VEC2/WAVES',
#            'VIA/BTC',
#            'VIA/DOGE',
#            'VIA/ETH',
#            'VIA/USD',
#            'VIA/WAVES',
#            'VIDZ/BTC',
#            'VIDZ/DOGE',
#            'VIDZ/ETH',
#            'VIDZ/USD',
#            'VIDZ/WAVES',
#            'VIP/BTC',
#            'VIP/DOGE',
#            'VIP/ETH',
#            'VIP/USD',
#            'VIP/WAVES',
#            'VISIO/BTC',
#            'VISIO/DOGE',
#            'VISIO/ETH',
#            'VISIO/USD',
#            'VISIO/WAVES',
#            'VLT/BTC',
#            'VLT/DOGE',
#            'VLT/ETH',
#            'VLT/USD',
#            'VLT/WAVES',
#            'VOLT/BTC',
#            'VOLT/DOGE',
#            'VOLT/ETH',
#            'VOLT/USD',
#            'VOLT/WAVES',
#            'VOYA/BTC',
#            'VOYA/DOGE',
#            'VOYA/ETH',
#            'VOYA/USD',
#            'VOYA/WAVES',
#            'VPRC/BTC',
#            'VPRC/DOGE',
#            'VPRC/ETH',
#            'VPRC/USD',
#            'VPRC/WAVES',
#            'VTC/BTC',
#            'VTC/DOGE',
#            'VTC/ETH',
#            'VTC/USD',
#            'VTC/WAVES',
#            'VULC/BTC',
#            'VULC/DOGE',
#            'VULC/ETH',
#            'VULC/USD',
#            'VULC/WAVES',
#            'WARP/BTC',
#            'WARP/DOGE',
#            'WARP/ETH',
#            'WARP/USD',
#            'WARP/WAVES',
#            'WAVES/BTC',
#            'WAVES/DOGE',
#            'WAVES/ETH',
#            'WAVES/USD',
#            'WAY/BTC',
#            'WAY/DOGE',
#            'WAY/ETH',
#            'WAY/USD',
#            'WAY/WAVES',
#            'WBB/BTC',
#            'WBB/DOGE',
#            'WBB/ETH',
#            'WBB/USD',
#            'WBB/WAVES',
#            'WGO/BTC',
#            'WGO/DOGE',
#            'WGO/ETH',
#            'WGO/USD',
#            'WGO/WAVES',
#            'WGR/BTC',
#            'WGR/DOGE',
#            'WGR/ETH',
#            'WGR/USD',
#            'WGR/WAVES',
#            'WIC/BTC',
#            'WIC/DOGE',
#            'WIC/ETH',
#            'WIC/USD',
#            'WIC/WAVES',
#            'WINK/BTC',
#            'WINK/DOGE',
#            'WINK/ETH',
#            'WINK/USD',
#            'WINK/WAVES',
#            'WMC/BTC',
#            'WMC/DOGE',
#            'WMC/ETH',
#            'WMC/USD',
#            'WMC/WAVES',
#            'WOMEN/BTC',
#            'WOMEN/DOGE',
#            'WOMEN/ETH',
#            'WOMEN/USD',
#            'WOMEN/WAVES',
#            'WRC/BTC',
#            'WRC/DOGE',
#            'WRC/ETH',
#            'WRC/USD',
#            'WRC/WAVES',
#            'WTT/BTC',
#            'WTT/DOGE',
#            'WTT/ETH',
#            'WTT/USD',
#            'WTT/WAVES',
#            'X2/BTC',
#            'X2/DOGE',
#            'X2/ETH',
#            'X2/USD',
#            'X2/WAVES',
#            'XAU/BTC',
#            'XAU/DOGE',
#            'XAU/ETH',
#            'XAU/USD',
#            'XAU/WAVES',
#            'XBTC21/BTC',
#            'XBTC21/DOGE',
#            'XBTC21/ETH',
#            'XBTC21/USD',
#            'XBTC21/WAVES',
#            'XBTS/BTC',
#            'XBTS/DOGE',
#            'XBTS/ETH',
#            'XBTS/USD',
#            'XBTS/WAVES',
#            'XBY/BTC',
#            'XBY/DOGE',
#            'XBY/ETH',
#            'XBY/USD',
#            'XBY/WAVES',
#            'XCO/BTC',
#            'XCO/DOGE',
#            'XCO/ETH',
#            'XCO/USD',
#            'XCO/WAVES',
#            'XCRE/BTC',
#            'XCRE/DOGE',
#            'XCRE/ETH',
#            'XCRE/USD',
#            'XCRE/WAVES',
#            'XDE2/BTC',
#            'XDE2/DOGE',
#            'XDE2/ETH',
#            'XDE2/USD',
#            'XDE2/WAVES',
#            'XEM/BTC',
#            'XEM/DOGE',
#            'XEM/ETH',
#            'XEM/USD',
#            'XEM/WAVES',
#            'XHI/BTC',
#            'XHI/DOGE',
#            'XHI/ETH',
#            'XHI/USD',
#            'XHI/WAVES',
#            'XIN/BTC',
#            'XIN/DOGE',
#            'XIN/ETH',
#            'XIN/USD',
#            'XIN/WAVES',
#            'XIOS/BTC',
#            'XIOS/DOGE',
#            'XIOS/ETH',
#            'XIOS/USD',
#            'XIOS/WAVES',
#            'XJO/BTC',
#            'XJO/DOGE',
#            'XJO/ETH',
#            'XJO/USD',
#            'XJO/WAVES',
#            'XMG/BTC',
#            'XMG/DOGE',
#            'XMG/ETH',
#            'XMG/USD',
#            'XMG/WAVES',
#            'XNG/BTC',
#            'XNG/DOGE',
#            'XNG/ETH',
#            'XNG/USD',
#            'XNG/WAVES',
#            'XOC/BTC',
#            'XOC/DOGE',
#            'XOC/ETH',
#            'XOC/USD',
#            'XOC/WAVES',
#            'XPD/BTC',
#            'XPD/DOGE',
#            'XPD/ETH',
#            'XPD/USD',
#            'XPD/WAVES',
#            'XPTX/BTC',
#            'XPTX/DOGE',
#            'XPTX/ETH',
#            'XPTX/USD',
#            'XPTX/WAVES',
#            'XPY/BTC',
#            'XPY/DOGE',
#            'XPY/ETH',
#            'XPY/USD',
#            'XPY/WAVES',
#            'XQN/BTC',
#            'XQN/DOGE',
#            'XQN/ETH',
#            'XQN/USD',
#            'XQN/WAVES',
#            'XRA/BTC',
#            'XRA/DOGE',
#            'XRA/ETH',
#            'XRA/USD',
#            'XRA/WAVES',
#            'XRL/BTC',
#            'XRL/DOGE',
#            'XRL/ETH',
#            'XRL/USD',
#            'XRL/WAVES',
#            'XVE/BTC',
#            'XVE/DOGE',
#            'XVE/ETH',
#            'XVE/USD',
#            'XVE/WAVES',
#            'XVG/BTC',
#            'XVG/DOGE',
#            'XVG/ETH',
#            'XVG/USD',
#            'XVG/WAVES',
#            'YAC/BTC',
#            'YAC/DOGE',
#            'YAC/ETH',
#            'YAC/USD',
#            'YAC/WAVES',
#            'YES/BTC',
#            'YES/DOGE',
#            'YES/ETH',
#            'YES/USD',
#            'YES/WAVES',
#            'ZEC/BTC',
#            'ZEC/DOGE',
#            'ZEC/ETH',
#            'ZEC/USD',
#            'ZEC/WAVES',
#            'ZEIT/BTC',
#            'ZEIT/DOGE',
#            'ZEIT/ETH',
#            'ZEIT/USD',
#            'ZEIT/WAVES',
#            'ZENI/BTC',
#            'ZENI/DOGE',
#            'ZENI/ETH',
#            'ZENI/USD',
#            'ZENI/WAVES',
#            'ZET/BTC',
#            'ZET/DOGE',
#            'ZET/ETH',
#            'ZET/USD',
#            'ZET/WAVES',
#            'ZMC/BTC',
#            'ZMC/DOGE',
#            'ZMC/ETH',
#            'ZMC/USD',
#            'ZMC/WAVES',
#            'ZNE/BTC',
#            'ZNE/DOGE',
#            'ZNE/ETH',
#            'ZNE/USD',
#            'ZNE/WAVES',
#            'ZRC/BTC',
#            'ZRC/DOGE',
#            'ZRC/ETH',
#            'ZRC/USD',
#            'ZRC/WAVES',
#            'ZUR/BTC',
#            'ZUR/DOGE',
#            'ZUR/ETH',
#            'ZUR/USD',
#            'ZUR/WAVES',
#            'ZYD/BTC',
#            'ZYD/DOGE',
#            'ZYD/ETH',
#            'ZYD/USD',
#            'ZYD/WAVES'},
#  'zaif': {'BCH/BTC',
#           'ETH/BTC',
#           'MONA/BTC',
#           'PEPECASH/BTC',
#           'SJCX/BTC',
#           'XCP/BTC',
#           'XEM/BTC'},
#  'zb': {'1ST/BTC',
#         '1ST/USDT',
#         'BAT/BTC',
#         'BAT/USDT',
#         'BCD/BTC',
#         'BCD/USDT',
#         'BCH/BTC',
#         'BCH/USDT',
#         'BCX/BTC',
#         'BCX/USDT',
#         'BTC/USDT',
#         'BTS/BTC',
#         'BTS/USDT',
#         'CHAT/BTC',
#         'CHAT/USDT',
#         'DASH/BTC',
#         'DASH/USDT',
#         'ENT/BTC',
#         'ENT/USDT',
#         'EOS/BTC',
#         'EOS/USDT',
#         'EPC/BTC',
#         'ETC/BTC',
#         'ETC/USDT',
#         'ETH/BTC',
#         'ETH/USDT',
#         'HLC/BTC',
#         'HLC/USDT',
#         'HSR/BTC',
#         'HSR/USDT',
#         'INK/BTC',
#         'INK/USDT',
#         'LBTC/BTC',
#         'LBTC/USDT',
#         'LTC/BTC',
#         'LTC/USDT',
#         'QTUM/BTC',
#         'QTUM/USDT',
#         'QUN/BTC',
#         'QUN/USDT',
#         'SBTC/BTC',
#         'SBTC/USDT',
#         'TOPC/BTC',
#         'TOPC/USDT',
#         'TRUE/BTC',
#         'TRUE/USDT',
#         'UBTC/BTC',
#         'UBTC/USDT',
#         'XRP/BTC',
#         'XRP/USDT',
#         'XUC/BTC'}}

# %%
#Now to print results for certain exchanges in copyable format for config.cfg file

selected_exchanges = ['binance','bitfinex', 'gdax', 'kraken']
metadata = {}

my_filter = {'ccex': [('TERA', 'BTC'), ('VRS', 'BTC')]}

for exch in selected_exchanges:
    market_tuples = []
    curr_markets = clean_exchanges_dict[exch]
    curr = {}
    for mkt in curr_markets:
        curr_tuple = tuple(mkt.split('/'))
        if exch in my_filter.keys():
            dont_include = my_filter[exch]
        else:
            dont_include = []
        if curr_tuple in dont_include:
            pass
        else:
            market_tuples.append(curr_tuple)
    curr[exch] = market_tuples
    print(curr)
    metadata[exch] = market_tuples
print("metadata:")
print(metadata)
# Out:
# {'binance': [('CMT', 'ETH'), ('RDN', 'BNB'), ('TRIG', 'BTC'), ('BTS', 'BTC'), ('ETC', 'BTC'), ('QTUM', 'ETH'), ('SNM', 'BTC'), ('AST', 'BTC'), ('OMG', 'BTC'), ('MTL', 'ETH'), ('BRD', 'BNB'), ('PIVX', 'BNB'), ('DLT', 'BTC'), ('FUEL', 'ETH'), ('MOD', 'ETH'), ('LSK', 'BNB'), ('RCN', 'BTC'), ('SNT', 'BTC'), ('TRIG', 'ETH'), ('MTH', 'ETH'), ('EVX', 'ETH'), ('ELF', 'ETH'), ('STORJ', 'BTC'), ('BCPT', 'BTC'), ('NAV', 'BNB'), ('XRP', 'BTC'), ('ARN', 'BTC'), ('MCO', 'ETH'), ('SALT', 'ETH'), ('XZC', 'BTC'), ('TRX', 'ETH'), ('RLC', 'BTC'), ('AMB', 'BTC'), ('NULS', 'BTC'), ('TRX', 'BTC'), ('HSR', 'BTC'), ('GXS', 'ETH'), ('LUN', 'ETH'), ('EOS', 'ETH'), ('MOD', 'BTC'), ('XMR', 'ETH'), ('NEBL', 'BNB'), ('DGD', 'BTC'), ('APPC', 'ETH'), ('EDO', 'BTC'), ('RCN', 'ETH'), ('ZEC', 'BTC'), ('BNB', 'ETH'), ('APPC', 'BTC'), ('AION', 'ETH'), ('CND', 'BNB'), ('DASH', 'ETH'), ('TNT', 'BTC'), ('LEND', 'ETH'), ('BAT', 'BTC'), ('BTG', 'BTC'), ('HSR', 'ETH'), ('BTS', 'ETH'), ('ADX', 'BNB'), ('VIBE', 'BTC'), ('SNGLS', 'ETH'), ('INS', 'ETH'), ('CND', 'ETH'), ('IOST', 'BTC'), ('BCH', 'ETH'), ('SALT', 'BTC'), ('MDA', 'ETH'), ('WTC', 'BNB'), ('AMB', 'BNB'), ('MTH', 'BTC'), ('OST', 'ETH'), ('TNB', 'BTC'), ('LSK', 'BTC'), ('ETH', 'BTC'), ('LSK', 'ETH'), ('NULS', 'BNB'), ('NEO', 'BTC'), ('BCD', 'ETH'), ('WAVES', 'BNB'), ('POE', 'BTC'), ('BRD', 'ETH'), ('XLM', 'ETH'), ('PPT', 'ETH'), ('QSP', 'BNB'), ('ARN', 'ETH'), ('WABI', 'BNB'), ('BNB', 'USDT'), ('POWR', 'BTC'), ('STEEM', 'BNB'), ('BNT', 'BTC'), ('MTL', 'BTC'), ('ICN', 'ETH'), ('OST', 'BTC'), ('RLC', 'ETH'), ('NAV', 'ETH'), ('QSP', 'BTC'), ('KMD', 'BTC'), ('KMD', 'ETH'), ('NEO', 'ETH'), ('AST', 'ETH'), ('BCH', 'USDT'), ('ARK', 'BTC'), ('NAV', 'BTC'), ('PPT', 'BTC'), ('AION', 'BTC'), ('GVT', 'ETH'), ('DNT', 'BTC'), ('VIBE', 'ETH'), ('POWR', 'ETH'), ('ADA', 'BTC'), ('TNB', 'ETH'), ('VEN', 'ETH'), ('DASH', 'BTC'), ('POWR', 'BNB'), ('BAT', 'ETH'), ('WINGS', 'BTC'), ('STRAT', 'ETH'), ('GTO', 'BTC'), ('DNT', 'ETH'), ('SUB', 'BTC'), ('EDO', 'ETH'), ('PIVX', 'BTC'), ('ZRX', 'BTC'), ('SNT', 'ETH'), ('ADX', 'BTC'), ('CHAT', 'ETH'), ('NEO', 'USDT'), ('CHAT', 'BTC'), ('QSP', 'ETH'), ('ADX', 'ETH'), ('INS', 'BTC'), ('ETH', 'USDT'), ('MANA', 'BTC'), ('LTC', 'BTC'), ('ENG', 'BTC'), ('KNC', 'ETH'), ('WTC', 'BTC'), ('PIVX', 'ETH'), ('OST', 'BNB'), ('SNM', 'ETH'), ('LRC', 'BTC'), ('NULS', 'ETH'), ('STRAT', 'BTC'), ('SNGLS', 'BTC'), ('BNB', 'BTC'), ('LRC', 'ETH'), ('GVT', 'BTC'), ('AMB', 'ETH'), ('EOS', 'BTC'), ('TNT', 'ETH'), ('WABI', 'BTC'), ('LUN', 'BTC'), ('MANA', 'ETH'), ('QTUM', 'BTC'), ('ENG', 'ETH'), ('IOST', 'ETH'), ('APPC', 'BNB'), ('MDA', 'BTC'), ('ARK', 'ETH'), ('CMT', 'BTC'), ('WINGS', 'ETH'), ('FUEL', 'BTC'), ('XZC', 'BNB'), ('LEND', 'BTC'), ('STEEM', 'BTC'), ('RCN', 'BNB'), ('GXS', 'BTC'), ('ZEC', 'ETH'), ('WAVES', 'ETH'), ('BRD', 'BTC'), ('BCPT', 'BNB'), ('LINK', 'ETH'), ('RLC', 'BNB'), ('BCD', 'BTC'), ('CMT', 'BNB'), ('XLM', 'BNB'), ('REQ', 'ETH'), ('DLT', 'BNB'), ('DGD', 'ETH'), ('WABI', 'ETH'), ('VIB', 'ETH'), ('VEN', 'BNB'), ('BCH', 'BNB'), ('GAS', 'BTC'), ('LINK', 'BTC'), ('BAT', 'BNB'), ('BTS', 'BNB'), ('STEEM', 'ETH'), ('OAX', 'BTC'), ('MCO', 'BNB'), ('SUB', 'ETH'), ('CDT', 'ETH'), ('OAX', 'ETH'), ('DLT', 'ETH'), ('XVG', 'ETH'), ('XVG', 'BTC'), ('OMG', 'ETH'), ('AION', 'BNB'), ('ENJ', 'ETH'), ('RDN', 'BTC'), ('WAVES', 'BTC'), ('ELF', 'BTC'), ('NEBL', 'ETH'), ('XRP', 'ETH'), ('LTC', 'BNB'), ('XMR', 'BTC'), ('VEN', 'BTC'), ('GTO', 'ETH'), ('LTC', 'ETH'), ('CTR', 'BTC'), ('NEBL', 'BTC'), ('FUN', 'ETH'), ('BCPT', 'ETH'), ('CDT', 'BTC'), ('CTR', 'ETH'), ('CND', 'BTC'), ('XZC', 'ETH'), ('XLM', 'BTC'), ('BNT', 'ETH'), ('MCO', 'BTC'), ('GTO', 'BNB'), ('KNC', 'BTC'), ('ICX', 'ETH'), ('TRIG', 'BNB'), ('FUN', 'BTC'), ('POE', 'ETH'), ('BCH', 'BTC'), ('BTC', 'USDT'), ('LTC', 'USDT'), ('ICX', 'BTC'), ('ENJ', 'BTC'), ('WTC', 'ETH'), ('ZRX', 'ETH'), ('ETC', 'ETH'), ('ICN', 'BTC'), ('EVX', 'BTC'), ('REQ', 'BTC'), ('RDN', 'ETH'), ('STORJ', 'ETH'), ('NEO', 'BNB'), ('VIB', 'BTC'), ('ICX', 'BNB'), ('ADA', 'ETH'), ('BTG', 'ETH')]}
# {'bitfinex': [('XRP', 'USD'), ('FUN', 'USD'), ('ETC', 'BTC'), ('QTUM', 'ETH'), ('ETP', 'ETH'), ('DAT', 'USD'), ('OMG', 'BTC'), ('AID', 'ETH'), ('SPK', 'ETH'), ('ETP', 'BTC'), ('LTC', 'USD'), ('EDO', 'USD'), ('SNT', 'BTC'), ('RCN', 'BTC'), ('ZEC', 'USD'), ('ELF', 'ETH'), ('XRP', 'BTC'), ('EOS', 'USD'), ('RLC', 'BTC'), ('TRX', 'ETH'), ('AVT', 'BTC'), ('SPK', 'USD'), ('TRX', 'BTC'), ('EOS', 'ETH'), ('EDO', 'BTC'), ('RCN', 'ETH'), ('ZEC', 'BTC'), ('GNT', 'BTC'), ('ELF', 'USD'), ('BAT', 'BTC'), ('BTG', 'BTC'), ('AVT', 'USD'), ('RLC', 'USD'), ('SNT', 'USD'), ('BCH', 'ETH'), ('TNB', 'BTC'), ('NEO', 'USD'), ('ETH', 'BTC'), ('GNT', 'USD'), ('NEO', 'BTC'), ('ETH', 'USD'), ('DAT', 'ETH'), ('QTUM', 'USD'), ('RLC', 'ETH'), ('GNT', 'ETH'), ('NEO', 'ETH'), ('SAN', 'USD'), ('OMG', 'USD'), ('AVT', 'ETH'), ('SAN', 'ETH'), ('TNB', 'ETH'), ('XMR', 'USD'), ('DASH', 'BTC'), ('BAT', 'ETH'), ('ETP', 'USD'), ('RCN', 'USD'), ('EDO', 'ETH'), ('DAT', 'BTC'), ('REP', 'ETH'), ('TRX', 'USD'), ('ZRX', 'BTC'), ('SNT', 'ETH'), ('LTC', 'BTC'), ('BTG', 'USD'), ('ETC', 'USD'), ('AID', 'USD'), ('EOS', 'BTC'), ('QTUM', 'BTC'), ('BTC', 'USD'), ('SPK', 'BTC'), ('SAN', 'BTC'), ('AID', 'BTC'), ('REP', 'BTC'), ('BAT', 'USD'), ('OMG', 'ETH'), ('ELF', 'BTC'), ('TNB', 'USD'), ('XMR', 'BTC'), ('FUN', 'ETH'), ('BCH', 'USD'), ('FUN', 'BTC'), ('REP', 'USD'), ('BCH', 'BTC'), ('ZRX', 'USD'), ('ZRX', 'ETH'), ('DASH', 'USD')]}
# {'gdax': [('ETH', 'BTC'), ('ETH', 'USD'), ('LTC', 'BTC'), ('BCH', 'USD'), ('BTC', 'USD'), ('LTC', 'USD'), ('BCH', 'BTC')]}
# {'kraken': [('XRP', 'USD'), ('REP', 'ETH'), ('ETC', 'BTC'), ('REP', 'BTC'), ('MLN', 'BTC'), ('MLN', 'ETH'), ('LTC', 'USD'), ('ETH', 'BTC'), ('LTC', 'BTC'), ('ZEC', 'USD'), ('ETC', 'USD'), ('XMR', 'BTC'), ('XRP', 'BTC'), ('ETH', 'USD'), ('XLM', 'BTC'), ('EOS', 'BTC'), ('GNO', 'ETH'), ('BCH', 'USD'), ('ICN', 'ETH'), ('EOS', 'ETH'), ('USDT', 'USD'), ('BCH', 'BTC'), ('ZEC', 'BTC'), ('GNO', 'BTC'), ('ETH', 'CAD'), ('ETC', 'ETH'), ('ICN', 'BTC'), ('XMR', 'USD'), ('DASH', 'BTC'), ('BTC', 'USD'), ('BTC', 'CAD'), ('DASH', 'USD')]}
# metadata:
# {'binance': [('CMT', 'ETH'), ('RDN', 'BNB'), ('TRIG', 'BTC'), ('BTS', 'BTC'), ('ETC', 'BTC'), ('QTUM', 'ETH'), ('SNM', 'BTC'), ('AST', 'BTC'), ('OMG', 'BTC'), ('MTL', 'ETH'), ('BRD', 'BNB'), ('PIVX', 'BNB'), ('DLT', 'BTC'), ('FUEL', 'ETH'), ('MOD', 'ETH'), ('LSK', 'BNB'), ('RCN', 'BTC'), ('SNT', 'BTC'), ('TRIG', 'ETH'), ('MTH', 'ETH'), ('EVX', 'ETH'), ('ELF', 'ETH'), ('STORJ', 'BTC'), ('BCPT', 'BTC'), ('NAV', 'BNB'), ('XRP', 'BTC'), ('ARN', 'BTC'), ('MCO', 'ETH'), ('SALT', 'ETH'), ('XZC', 'BTC'), ('TRX', 'ETH'), ('RLC', 'BTC'), ('AMB', 'BTC'), ('NULS', 'BTC'), ('TRX', 'BTC'), ('HSR', 'BTC'), ('GXS', 'ETH'), ('LUN', 'ETH'), ('EOS', 'ETH'), ('MOD', 'BTC'), ('XMR', 'ETH'), ('NEBL', 'BNB'), ('DGD', 'BTC'), ('APPC', 'ETH'), ('EDO', 'BTC'), ('RCN', 'ETH'), ('ZEC', 'BTC'), ('BNB', 'ETH'), ('APPC', 'BTC'), ('AION', 'ETH'), ('CND', 'BNB'), ('DASH', 'ETH'), ('TNT', 'BTC'), ('LEND', 'ETH'), ('BAT', 'BTC'), ('BTG', 'BTC'), ('HSR', 'ETH'), ('BTS', 'ETH'), ('ADX', 'BNB'), ('VIBE', 'BTC'), ('SNGLS', 'ETH'), ('INS', 'ETH'), ('CND', 'ETH'), ('IOST', 'BTC'), ('BCH', 'ETH'), ('SALT', 'BTC'), ('MDA', 'ETH'), ('WTC', 'BNB'), ('AMB', 'BNB'), ('MTH', 'BTC'), ('OST', 'ETH'), ('TNB', 'BTC'), ('LSK', 'BTC'), ('ETH', 'BTC'), ('LSK', 'ETH'), ('NULS', 'BNB'), ('NEO', 'BTC'), ('BCD', 'ETH'), ('WAVES', 'BNB'), ('POE', 'BTC'), ('BRD', 'ETH'), ('XLM', 'ETH'), ('PPT', 'ETH'), ('QSP', 'BNB'), ('ARN', 'ETH'), ('WABI', 'BNB'), ('BNB', 'USDT'), ('POWR', 'BTC'), ('STEEM', 'BNB'), ('BNT', 'BTC'), ('MTL', 'BTC'), ('ICN', 'ETH'), ('OST', 'BTC'), ('RLC', 'ETH'), ('NAV', 'ETH'), ('QSP', 'BTC'), ('KMD', 'BTC'), ('KMD', 'ETH'), ('NEO', 'ETH'), ('AST', 'ETH'), ('BCH', 'USDT'), ('ARK', 'BTC'), ('NAV', 'BTC'), ('PPT', 'BTC'), ('AION', 'BTC'), ('GVT', 'ETH'), ('DNT', 'BTC'), ('VIBE', 'ETH'), ('POWR', 'ETH'), ('ADA', 'BTC'), ('TNB', 'ETH'), ('VEN', 'ETH'), ('DASH', 'BTC'), ('POWR', 'BNB'), ('BAT', 'ETH'), ('WINGS', 'BTC'), ('STRAT', 'ETH'), ('GTO', 'BTC'), ('DNT', 'ETH'), ('SUB', 'BTC'), ('EDO', 'ETH'), ('PIVX', 'BTC'), ('ZRX', 'BTC'), ('SNT', 'ETH'), ('ADX', 'BTC'), ('CHAT', 'ETH'), ('NEO', 'USDT'), ('CHAT', 'BTC'), ('QSP', 'ETH'), ('ADX', 'ETH'), ('INS', 'BTC'), ('ETH', 'USDT'), ('MANA', 'BTC'), ('LTC', 'BTC'), ('ENG', 'BTC'), ('KNC', 'ETH'), ('WTC', 'BTC'), ('PIVX', 'ETH'), ('OST', 'BNB'), ('SNM', 'ETH'), ('LRC', 'BTC'), ('NULS', 'ETH'), ('STRAT', 'BTC'), ('SNGLS', 'BTC'), ('BNB', 'BTC'), ('LRC', 'ETH'), ('GVT', 'BTC'), ('AMB', 'ETH'), ('EOS', 'BTC'), ('TNT', 'ETH'), ('WABI', 'BTC'), ('LUN', 'BTC'), ('MANA', 'ETH'), ('QTUM', 'BTC'), ('ENG', 'ETH'), ('IOST', 'ETH'), ('APPC', 'BNB'), ('MDA', 'BTC'), ('ARK', 'ETH'), ('CMT', 'BTC'), ('WINGS', 'ETH'), ('FUEL', 'BTC'), ('XZC', 'BNB'), ('LEND', 'BTC'), ('STEEM', 'BTC'), ('RCN', 'BNB'), ('GXS', 'BTC'), ('ZEC', 'ETH'), ('WAVES', 'ETH'), ('BRD', 'BTC'), ('BCPT', 'BNB'), ('LINK', 'ETH'), ('RLC', 'BNB'), ('BCD', 'BTC'), ('CMT', 'BNB'), ('XLM', 'BNB'), ('REQ', 'ETH'), ('DLT', 'BNB'), ('DGD', 'ETH'), ('WABI', 'ETH'), ('VIB', 'ETH'), ('VEN', 'BNB'), ('BCH', 'BNB'), ('GAS', 'BTC'), ('LINK', 'BTC'), ('BAT', 'BNB'), ('BTS', 'BNB'), ('STEEM', 'ETH'), ('OAX', 'BTC'), ('MCO', 'BNB'), ('SUB', 'ETH'), ('CDT', 'ETH'), ('OAX', 'ETH'), ('DLT', 'ETH'), ('XVG', 'ETH'), ('XVG', 'BTC'), ('OMG', 'ETH'), ('AION', 'BNB'), ('ENJ', 'ETH'), ('RDN', 'BTC'), ('WAVES', 'BTC'), ('ELF', 'BTC'), ('NEBL', 'ETH'), ('XRP', 'ETH'), ('LTC', 'BNB'), ('XMR', 'BTC'), ('VEN', 'BTC'), ('GTO', 'ETH'), ('LTC', 'ETH'), ('CTR', 'BTC'), ('NEBL', 'BTC'), ('FUN', 'ETH'), ('BCPT', 'ETH'), ('CDT', 'BTC'), ('CTR', 'ETH'), ('CND', 'BTC'), ('XZC', 'ETH'), ('XLM', 'BTC'), ('BNT', 'ETH'), ('MCO', 'BTC'), ('GTO', 'BNB'), ('KNC', 'BTC'), ('ICX', 'ETH'), ('TRIG', 'BNB'), ('FUN', 'BTC'), ('POE', 'ETH'), ('BCH', 'BTC'), ('BTC', 'USDT'), ('LTC', 'USDT'), ('ICX', 'BTC'), ('ENJ', 'BTC'), ('WTC', 'ETH'), ('ZRX', 'ETH'), ('ETC', 'ETH'), ('ICN', 'BTC'), ('EVX', 'BTC'), ('REQ', 'BTC'), ('RDN', 'ETH'), ('STORJ', 'ETH'), ('NEO', 'BNB'), ('VIB', 'BTC'), ('ICX', 'BNB'), ('ADA', 'ETH'), ('BTG', 'ETH')], ' ...
